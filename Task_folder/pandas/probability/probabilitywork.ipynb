# %%
import pandas as pd 
import numpy as np
from zipfile import ZipFile
from functools import reduce
import matplotlib.pyplot as plt
from scipy import stats
import os

# %%
path= r"C:\Users\ncc\Downloads\archive.zip"
extracted_file = 'data_files'

# %%
with ZipFile(path,'r') as f:
    f.extractall('data_files')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 with ZipFile(path,'r') as f:
#       2     f.extractall('data_files')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\zipfile\__init__.py:1367, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1365 while True:
#    1366     try:
# -> 1367         self.fp = io.open(file, filemode)
#    1368     except OSError:
#    1369         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\ncc(Admin)\\Downloads\\archive.zip'
